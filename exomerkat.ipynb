# %%
import pyvo as vo
service = vo.dal.TAPService("http://archives.ia2.inaf.it/vo/tap/projects/")
resultset = service.search("SELECT TOP 1000 * FROM exomercat.exomercat")

# %%
resultset.to_table().show_in_browser()

# %%
service.search("SELECT COUNT(*) FROM exomercat.exomercat")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/Documents/CodingProjects/SemesterProjectEHG/.venv/lib64/python3.14/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Documents/CodingProjects/SemesterProjectEHG/.venv/lib64/python3.14/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File /usr/lib64/python3.14/http/client.py:1450, in HTTPConnection.getresponse(self)
#    1449 try:
# -> 1450     response.begin()
# ...
