# %% [markdown]
# # count-density grid split by spectral category
# - rows: spectral categories, columns: crossmatched sample vs entire Exo-MerCat
# - exports to `report/figures/radius_insolation_heatmap_by_spectral_category.pdf`

# %%
# %load_ext autoreload
# %autoreload 2

import os, sys, pathlib

ROOT = pathlib.Path.cwd()
while not (ROOT / 'crossmatching').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import matplotlib.pyplot as plt

from report_plots import common, data, plots

# %%
cme, input_table, matched = data.emc_crossmatch()
merger = data.build_param_filler()

e_cm_emc = data.enrich(matched, cme, merger)
e_emc = data.enrich(cme.catalog_table, cme, merger)
data.compute_is_rocky_temperate(e_cm_emc)
data.compute_is_rocky_temperate(e_emc)
data.rocky_temperate_summary(e_cm_emc=e_cm_emc, e_emc=e_emc)

# %%
plots.spectral_grid_heatmap(
    [e_cm_emc, e_emc],
    [r"HPIC$\times$LIFEcat $\otimes$ Exo-MerCat", "entire Exo-MerCat"],
    common.CATEGORY_ORDER,
    figsize=(8, 11),
)
common.save_figure("radius_insolation_heatmap_by_spectral_category")
